# %%
import os
import pandas as pd
diretorio = 'data'
caminho_pasta = f"{diretorio}/dictionary.csv"
os.makedirs(diretorio, exist_ok = True)

data_dictionary = pd.DataFrame([
    {
        'variavel' : 'user_id',
        'descricao' : 'Chave única do usuário',
        'tipo' : 'qualitativo',
        'subtipo' : 'nominal'
    } ,
    
    { 
        'variavel' : 'gender',
        'descricao' : 'Gênero do usuário (Feminino/Masculino/Outro)',
        'tipo' : 'qualitativa',
        'subtipo' : 'nominal'
    },
     
    {
        'variavel' : 'age',
        'descricao' : 'Idade do Usuário',
        'tipo' : 'quantitativa',
        'subtipo' : 'contínua'
    },
    
    {
        'variavel' : 'country',
        'descricao' : 'Localização do usuário pelo país',
        'tipo' : 'qualitativa' ,
        'subtipo' : 'nominal'
    },
    
    {
        'variavel' : 'subscription_type',
        'descricao' : 'Tipo de assinatura do usuário (Plano gratuito/Família/Estudante) ',
        'tipo' : 'qualitativa' ,
        'subtipo' : 'nominal'
    },
    
    {
        'variavel' : 'listening_time',
        'descricao' : 'Minutos gastos ouvindo por dia' ,
        'tipo' : ' quantitativa' ,
        'subtipo': 'contínua'
    } ,
    
    {
        'variavel' : 'songs_played_per_day',
        'descricao' : 'Número de músicas tocadas diariamente' ,
        'tipo' : 'qualitativa' ,
        'subtipo' : 'discreta' 
    } ,

    {
        'variavel' : 'skip_rate',
        'descricao' : 'Percentual de músicas puladasv' ,
        'tipo' : 'quantitativa' ,
        'subtipo' : 'contínua' 
    } ,
    {
        'variavel' : 'ads_listened_per_week',
        'descricao' : 'Número de anúncios ouvidos por semana' ,
        'tipo' : 'quantitativa' ,
        'subtipo' : 'discreta' 
    } ,
    {
        'variavel' : 'offline_listening',
        'descricao' : 'Uso do modo offline (Sim/Não)' ,
        'tipo' : 'qualitativo (binário)' ,
        'subtipo' : 'nominal' 
    } , 
      {
        'variavel' : 'offline_listening',
        'descricao' : 'Uso do modo offline (Sim/Não)' ,
        'tipo' : 'qualitativo (binário)' ,
        'subtipo' : 'nominal' 
    } ,  
    {
        'variavel' : 'is_churned',
        'descricao' : 'Usuário cancelou (0 = ativo, 1 = churned)' ,
        'tipo' : 'qualitativo (binário)' ,
        'subtipo' : 'nominal' 
    } ,
])
 
data_dictionary.to_csv(caminho_pasta , index = False)
